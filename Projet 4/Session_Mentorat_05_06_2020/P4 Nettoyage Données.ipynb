# %% [markdown]
# ## Table des matières

# %% [markdown]
# - [Identification des données à nettoyer](#nettoyage)
#     - [Fichier customers](#customers)
#     - [Fichier products](#products)
#     - [Fichier transactions](#transactions)
# - [Scripts de nettoyage](#script)
#    - [Fichier products](#script_products)
#    - [Fichier transactions](#script_transactions)

# %%
import numpy as np
import pandas as pd

# %%
customers=pd.read_csv('customers.csv')
products = pd.read_csv('products.csv')
transactions = pd.read_csv('transactions.csv')

# %% [markdown]
# <a id="nettoyage"></a>
# ## Identification des données à nettoyer

# %% [markdown]
# <a id="customers"></a>
# ### Fichier customers

# %%
customers
# Out:
#      client_id sex  birth
# 0       c_4410   f   1967
# 1       c_7839   f   1975
# 2       c_1699   f   1984
# 3       c_5961   f   1962
# 4       c_5320   m   1943
# ...        ...  ..    ...
# 8618    c_7920   m   1956
# 8619    c_7403   f   1970
# 8620    c_5119   m   1974
# 8621    c_5643   f   1968
# 8622      c_84   f   1982
#
# [8623 rows x 3 columns]

# %%
customers.birth.unique()

# Les valeurs de 'birth' sont cohérentes
# Out:
# array([1967, 1975, 1984, 1962, 1943, 1993, 1978, 1971, 1982, 1945, 2003,
#        1959, 1977, 1954, 1987, 2000, 1992, 1963, 1958, 1994, 1936, 1986,
#        1942, 1970, 1957, 1968, 2002, 2004, 1979, 1974, 1964, 1951, 1937,
#        1981, 1965, 1960, 1996, 1983, 1990, 1955, 1988, 1991, 1972, 1980,
#        1989, 1976, 1985, 1953, 1998, 1956, 1948, 1973, 1969, 1938, 1995,
#        1952, 1949, 1999, 2001, 1939, 1950, 1966, 1935, 1941, 1961, 1997,
#        1944, 1929, 1947, 1946, 1932, 1931, 1933, 1930, 1940, 1934])

# %%
customers.sex.unique()

# Les valeurs de 'sex' sont cohérentes
# Out:
# array(['f', 'm'], dtype=object)

# %%
customers.client_id.unique()

# Les valeurs de 'client_id' sont cohérentes
# Out:
# array(['c_4410', 'c_7839', 'c_1699', ..., 'c_5119', 'c_5643', 'c_84'],
#       dtype=object)

# %%
customers.duplicated(subset='client_id').sum()

# Pas de doublons
# Out:
# 0

# %%
customers.isnull()

# Pas de valeur nulle
# Out:
#       client_id    sex  birth
# 0         False  False  False
# 1         False  False  False
# 2         False  False  False
# 3         False  False  False
# 4         False  False  False
# ...         ...    ...    ...
# 8618      False  False  False
# 8619      False  False  False
# 8620      False  False  False
# 8621      False  False  False
# 8622      False  False  False
#
# [8623 rows x 3 columns]

# %%
customers.dtypes
# Out:
# client_id    object
# sex          object
# birth         int64
# dtype: object

# %% [markdown]
# ### Le fichier 'customers':
# - n'a pas de doublons de client
# - n'a pas de valeur de date de naissance aberrente
# - les variables sont des objets pour les colonnes 'client_id' et 'sex'
# - les variables sont des entiers pour la colonne 'birth'
#
# ## Fichier 'customers' Ok

# %%
customers_clean = customers

customers_clean.to_csv("customers_clean.csv", index=False)

# %% [markdown]
# <a id="products"></a>
# ### Fichier products

# %%
products
# Out:
#      id_prod   price  categ
# 0     0_1421   19.99      0
# 1     0_1368    5.13      0
# 2      0_731   17.99      0
# 3      1_587    4.99      1
# 4     0_1507    3.99      0
# ...      ...     ...    ...
# 3282    2_23  115.99      2
# 3283   0_146   17.14      0
# 3284   0_802   11.22      0
# 3285   1_140   38.56      1
# 3286  0_1920   25.16      0
#
# [3287 rows x 3 columns]

# %%
products.dtypes
# Out:
# id_prod     object
# price      float64
# categ        int64
# dtype: object

# %%
products.categ.unique()
# Out:
# array([0, 1, 2])

# %%
products.price.min()

# Valeurs négatives à supprimer
# Out:
# -1.0

# %%
products.sort_values(by='price').head()

# Une valeur négative à supprimer
# Out:
#      id_prod  price  categ
# 731      T_0  -1.00      0
# 2355   0_202   0.62      0
# 2272   0_528   0.62      0
# 370    0_120   0.66      0
# 1211  0_1844   0.77      0

# %%
products.id_prod.unique()
# Out:
# array(['0_1421', '0_1368', '0_731', ..., '0_802', '1_140', '0_1920'],
#       dtype=object)

# %%
products.duplicated().sum()
# Out:
# 0

# %%
products.describe()

# Prix max de 300$ largement supérieur à moyenne à 75%
# Out:
#              price        categ
# count  3287.000000  3287.000000
# mean     21.856641     0.370246
# std      29.847908     0.615387
# min      -1.000000     0.000000
# 25%       6.990000     0.000000
# 50%      13.060000     0.000000
# 75%      22.990000     1.000000
# max     300.000000     2.000000

# %%
products.sort_values(by='price').tail(60)

# Les prix augmentent graduellement jusqu'à la valeur max. Valeur '300' cohérente.
# Out:
#      id_prod   price  categ
# 1888   2_203  136.99      2
# 2128   2_199  136.99      2
# 2808   2_198  138.32      2
# 2733   2_194  138.53      2
# 2207   2_153  139.99      2
# 1779    2_35  139.99      2
# 1946    2_72  141.32      2
# 3151   2_130  142.58      2
# 1323   2_157  142.99      2
# 1570   2_189  142.99      2
# 2568    2_29  142.99      2
# 706     2_94  145.45      2
# 2977    2_77  145.99      2
# 1315   2_159  145.99      2
# 3271   2_123  147.99      2
# 3088    2_98  149.74      2
# 2897    2_50  150.69      2
# 2308    2_66  150.72      2
# 1117   2_173  155.99      2
# 104    2_151  156.99      2
# 297    2_144  157.42      2
# 1011   2_150  157.63      2
# 107    2_103  157.99      2
# 73     2_225  157.99      2
# 79     2_187  157.99      2
# 117    2_172  158.17      2
# 2760   2_141  158.99      2
# 2698    2_97  160.99      2
# 432      2_0  162.03      2
# 1390    2_64  163.94      2
# 2106   2_119  164.99      2
# 2350   2_132  166.21      2
# 214     2_78  167.49      2
# 562    2_121  170.99      2
# 925    2_233  172.99      2
# 1371   2_190  175.67      2
# 719    2_223  175.99      2
# 1351   2_178  176.20      2
# 792    2_147  181.99      2
# 2164    2_90  182.30      2
# 1729    2_84  182.30      2
# 2472   2_156  188.48      2
# 1675   2_213  189.99      2
# 970      2_5  191.99      2
# 2993   2_235  195.99      2
# 95     2_128  201.74      2
# 3163    2_11  201.99      2
# 2464     2_3  202.99      2
# 1284   2_211  203.99      2
# 1709    2_87  220.99      2
# 1896     2_4  222.97      2
# 10     2_228  225.17      2
# 786     2_40  228.11      2
# 2487   2_166  230.04      2
# 1960   2_125  231.99      2
# 2779    2_30  233.54      2
# 1436   2_167  236.99      2
# 394    2_158  247.22      2
# 724     2_76  254.44      2
# 947      2_2  300.00      2

# %%
products.notna()

# Pas de valeurs manquantes
# Out:
#       id_prod  price  categ
# 0        True   True   True
# 1        True   True   True
# 2        True   True   True
# 3        True   True   True
# 4        True   True   True
# ...       ...    ...    ...
# 3282     True   True   True
# 3283     True   True   True
# 3284     True   True   True
# 3285     True   True   True
# 3286     True   True   True
#
# [3287 rows x 3 columns]

# %% [markdown]
# ### Le fichier 'products':
# - n'a pas de doublons de produits
# - les variables sont des objets pour la colonne 'id_prod'
# - les variables sont des décimaux pour la colonne 'price'
# - les variables sont des entiers pour la colonne 'categ'
#
#
# ### Le fichier 'products' ne doit pas avoir de valeur de prix négative.

# %% [markdown]
# <a id="transactions"></a>
# ### Fichier transactions

# %%
transactions
# Out:
#        id_prod                        date session_id client_id
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3       0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4       0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
# ...        ...                         ...        ...       ...
# 337011   1_671  2021-05-28 12:35:46.214839    s_40720    c_3454
# 337012   0_759  2021-06-19 00:19:23.917703    s_50568    c_6268
# 337013  0_1256  2021-03-16 17:31:59.442007     s_7219    c_4137
# 337014   2_227  2021-10-30 16:50:15.997750   s_112349       c_5
# 337015  0_1417  2021-06-26 14:38:19.732946    s_54117    c_6714
#
# [337016 rows x 4 columns]

# %%
transactions.dtypes

# Les dates sont des objets et non pas des datetime64
# Out:
# id_prod       object
# date          object
# session_id    object
# client_id     object
# dtype: object

# %%
transactions.isnull()

# Pas de valeurs manquantes
# Out:
#         id_prod   date  session_id  client_id
# 0         False  False       False      False
# 1         False  False       False      False
# 2         False  False       False      False
# 3         False  False       False      False
# 4         False  False       False      False
# ...         ...    ...         ...        ...
# 337011    False  False       False      False
# 337012    False  False       False      False
# 337013    False  False       False      False
# 337014    False  False       False      False
# 337015    False  False       False      False
#
# [337016 rows x 4 columns]

# %%
transactions.duplicated().sum()

#Il y a 126 doublons à supprimer
# Out:
# 126

# %%
transactions.sort_values(by="id_prod").tail(200)

# Il y a 200 valeurs test à supprimer
# Out:
#        id_prod                             date session_id client_id
# 7283       T_0  test_2021-03-01 02:30:02.237434        s_0      ct_1
# 256011     T_0  test_2021-03-01 02:30:02.237420        s_0      ct_1
# 252328     T_0  test_2021-03-01 02:30:02.237440        s_0      ct_0
# 129851     T_0  test_2021-03-01 02:30:02.237425        s_0      ct_0
# 141636     T_0  test_2021-03-01 02:30:02.237443        s_0      ct_1
# ...        ...                              ...        ...       ...
# 47170      T_0  test_2021-03-01 02:30:02.237430        s_0      ct_1
# 259134     T_0  test_2021-03-01 02:30:02.237418        s_0      ct_0
# 2365       T_0  test_2021-03-01 02:30:02.237446        s_0      ct_1
# 271894     T_0  test_2021-03-01 02:30:02.237444        s_0      ct_1
# 34387      T_0  test_2021-03-01 02:30:02.237443        s_0      ct_0
#
# [200 rows x 4 columns]

# %% [markdown]
# <a id="script"></a>
# ## Scripts de nettoyage

# %% [markdown]
# <a id="script_products"></a>
# ### Fichier products

# %%
products_work = products.copy()

# %%
products_clean = products_work.drop(products_work[products_work.price<0].index)

# %%
products_clean.to_csv("products_clean", index=False)

# %% [markdown]
# <a id="script_transactions"></a>
# ### Fichier transactions

# %%
transactions_work = transactions.copy()

# %%
# Suppression des doublons

transactions_work.drop_duplicates()
# Out:
#        id_prod                        date session_id client_id
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3       0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4       0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
# ...        ...                         ...        ...       ...
# 337011   1_671  2021-05-28 12:35:46.214839    s_40720    c_3454
# 337012   0_759  2021-06-19 00:19:23.917703    s_50568    c_6268
# 337013  0_1256  2021-03-16 17:31:59.442007     s_7219    c_4137
# 337014   2_227  2021-10-30 16:50:15.997750   s_112349       c_5
# 337015  0_1417  2021-06-26 14:38:19.732946    s_54117    c_6714
#
# [336890 rows x 4 columns]

# %%
# Suppression des valeurs test

def remove_test_values(df):
    df = df[df['id_prod'].str.contains('T_0') == False]
    df = df[df['date'].str.contains('test_') == False]
    return df

# %%
transactions_work = remove_test_values(transactions_work)

# %%
# Conversion des valeurs de 'date' en datetime

transactions_work['date'] = pd.to_datetime(transactions_work['date'], infer_datetime_format=True)

# %%
transactions_work.dtypes
# Out:
# id_prod               object
# date          datetime64[ns]
# session_id            object
# client_id             object
# dtype: object

# %%
# Création des colones 'year', 'month', et 'day' depuis la colonne 'date'

def extract_date_info(df):
    df['day'] = df['date'].dt.day 
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    
extract_date_info(transactions_work)

# %%
transactions_work
# Out:
#        id_prod                       date session_id client_id  day  month  \
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450   10      4
# 1        2_226 2022-02-03 01:55:53.276402   s_159142     c_277    3      2
# 2        1_374 2021-09-23 15:13:46.938559    s_94290    c_4270   23      9
# 3       0_2186 2021-10-17 03:27:18.783634   s_105936    c_4597   17     10
# 4       0_1351 2021-07-17 20:34:25.800563    s_63642    c_1242   17      7
# ...        ...                        ...        ...       ...  ...    ...
# 337011   1_671 2021-05-28 12:35:46.214839    s_40720    c_3454   28      5
# 337012   0_759 2021-06-19 00:19:23.917703    s_50568    c_6268   19      6
# 337013  0_1256 2021-03-16 17:31:59.442007     s_7219    c_4137   16      3
# 337014   2_227 2021-10-30 16:50:15.997750   s_112349       c_5   30     10
# 337015  0_1417 2021-06-26 14:38:19.732946    s_54117    c_6714   26      6
#
#         year
# 0       2021
# 1       2022
# 2       2021
# 3       2021
# 4       2021
# ...      ...
# 337011  2021
# 337012  2021
# 337013  2021
# 337014  2021
# 337015  2021
#
# [336816 rows x 7 columns]

# %%
transactions_clean = transactions_work

transactions_clean.to_csv("transactions_clean.csv", index=False)

# Lors de l'import des tables dans le script 'analyses'
# Des colonnes 'Unnamed' apparaissaient après la jointure de ces trois tableaux
# en rajoutant le paramètre 'index=False' dans l'export csv
# Ces colonnes 'Unnamed' n'apparaissent plus
