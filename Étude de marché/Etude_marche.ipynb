# %% [markdown]
# ## Table des matières

# %% [markdown]
# - [Création de l'échantillon 'data'](#chapitre_1)
# - [Méthode du dendrogramme](#chapitre_2)
#     - [Dendrogramme](#chapitre_2_1)
#     - [Coupage du dendrogramme en 5 clusters](#chapitre_2_3)
#     - [Nombre de pays par clusters](#chapitre_2_4)
#     - [Analyse en composantes principales](#chapitre_2_5)
#     - [Calcul des composantes principales et moyennes](#chapitre_2_6)
# - [Caractérisation des clusters selon les variables : méthode K-Means](#chapitre_3)
# - [Visualisation dans le premier plan factoriel obtenu par ACP](#chapitre_4)
#     - [Méthode du dendrogramme](#chapitre_4_1)
#     - [Méthode K-Means](#chapitre_4_2)
# - [Liste des pays à cibler](#chapitre_5)
# - [Caractéristiques des pays à cibler](#chapitre_6)
# - [Tests d'adéquation](#chapitre_7)
# - [Test de comparaison](#chapitre_8)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.collections import LineCollection
from sklearn import decomposition, preprocessing
from scipy.cluster.hierarchy import dendrogram
import warnings
warnings.filterwarnings('ignore')

population = pd.read_csv("population_2016_2017.csv")
dispAlim = pd.read_csv("disp_alim_totale_2017.csv")
dispAlimAnimaux = pd.read_csv("disp_alim_animaux_2017.csv")
PIBparHab = pd.read_csv("PIB_par_Hab.csv", sep=";", decimal = ",")

# %% [markdown]
# L'étude se base sur les chiffres de la FAO de l'année 2017.
#
# Le PIB par habitant provient de cette source : https://donnees.banquemondiale.org/
#
# Elle est complétée par les sources suivantes pour ces pays :
#    - République démocratique populaire de Corée : https://www.populationdata.net/pays/coree-du-nord/
#    - Djibouti : https://perspective.usherbrooke.ca/bilan/servlet/BMTendanceStatPays?langue=fr&codePays=DJI&codeStat=NY.GDP.PCAP.PP.CD&codeStat2=x
#    - Érythrée : https://fr.countryeconomy.com/gouvernement/pib/erythree
#    - Nouvelle-Calédonie : https://www.lefigaro.fr/economie/le-scan-eco/2017/12/02/29001-20171202ARTFIG00004-du-nickel-au-tourisme-8-choses-a-savoir-sur-l-economie-de-la-nouvelle-caledonie.php
#    - Polynésie française : http://www.polynesie-francaise.pref.gouv.fr/content/download/28076/146842/file/EC_Regards-eco-PF_oct2017.pdf (PIB 2016)
#    - Venezuela : https://fr.wikipedia.org/wiki/%C3%89conomie_du_Venezuela

# %% [markdown]
# <a id="chapitre_1"></a>
# ## <span style="color: #030aa4">Création de l'échantillon 'data'</span>

# %%
# Création de dataPop pour la population de chaque pays en 2016 et 2017 :

dataPop = population.loc[ : ,('Code zone','Zone','Année','Valeur')]\
                    .pivot_table(index = ['Code zone','Zone'], columns = 'Année', values='Valeur', aggfunc = sum)\
                    .reset_index()

# Vu dans projet 3 :
# La Chine apparaît deux fois :
# - Chine, continentale (Code zone = 41), donnée officielle
# - Chine (Code zone = 351), agrégat incluant des données non officielles

# Suppression de l'élément "Chine" avec le code zone : 

dataPop = dataPop[dataPop["Code zone"]!=351]

# Création colonne "Différence de population entre 2016 et 2017 en %" :

dataPop['diff_pop'] = ((dataPop[2017]-dataPop[2016])/dataPop[2016])*100

# Création de dataAlim pour la disponibilité alimentaire totale :

dataAlim = dispAlim.pivot_table(index =['Zone','Code zone'],
                            columns='Élément', values='Valeur', aggfunc = sum)\
                   .loc[ : ,('Disponibilité alimentaire (Kcal/personne/jour)',
                             'Disponibilité de protéines en quantité (g/personne/jour)')]\
                   .reset_index()\
                   .rename(columns={'Disponibilité alimentaire (Kcal/personne/jour)':'disp_alim',
                                    'Disponibilité de protéines en quantité (g/personne/jour)':'disp_prot'})
dataAlim['disp_alim'] *= 365
dataAlim['disp_prot'] *= 365

# Suppression des valeurs incohérentes :

dataAlim = dataAlim.drop(dataAlim[dataAlim['disp_alim']<0].index)\
                   .drop(dataAlim[dataAlim['disp_prot']<0].index)\
                   .drop_duplicates()

# Création de dataAnim pour la disponibilité alimentaire animale :

dataAnim = dispAlimAnimaux.pivot_table(index =['Zone','Code zone'],
                            columns='Élément', values='Valeur', aggfunc = sum)\
                          .loc[ : ,('Disponibilité de protéines en quantité (g/personne/jour)')]\
                          .reset_index()\
                          .rename(columns={'Disponibilité de protéines en quantité (g/personne/jour)':"Disponibilité d'origine animale de protéines en quantité (g/personne)"})
dataAnim["Disponibilité d'origine animale de protéines en quantité (g/personne)"] *= 365

# Suppression des valeurs incohérentes :

dataAnim = dataAnim.drop(dataAnim[dataAnim["Disponibilité d'origine animale de protéines en quantité (g/personne)"]<0].index)\
                   .drop_duplicates()

# Jointure de dataPop, dataAlim, dataAnim et PIBparHab : 

PIBparHab = PIBparHab.reset_index()\
                     .rename(columns={'PIB par hab.  En US Dollar 2017':"pib_hab"})

data = pd.merge(dataPop, dataAlim)
data = pd.merge(data, dataAnim)
data = pd.merge(data, PIBparHab)

data["prop_prot"] = (data["Disponibilité d'origine animale de protéines en quantité (g/personne)"]/data['disp_prot'])*100

data = data.drop(columns=['Code zone',2016,2017,"Disponibilité d'origine animale de protéines en quantité (g/personne)","index"])\
           .set_index('Zone')


data.tail(3)
# Out:
#             diff_pop  disp_alim  disp_prot      pib_hab  prop_prot
# Zone
# Serbie     -0.274792  1023825.0   30112.50  6560.323194  48.509091
# Monténégro  0.047827  1270565.0   41358.15  7845.368126  60.603654
# Soudan      2.424146   888045.0   24776.20  1900.092771  31.128462

# %% [markdown]
# Description des variables :
# - **diff_pop** : différence de population entre 2016 et 2017 en %
# - **disp_alim** : disponibilité alimentaire totale (Kcal/personne)
# - **disp_prot** : disponibilité totale de protéines en quantité (g/personne)
# - **pib_hab** : PIB par habitant en Dollar US
# - **prop_prot** : proportion de protéines d'origine animale par rapport à quantité totale de protéines dans disponibilité alimentaire en %
#
# Les pays à cibler doivent avoir :
# - une démographie en croissance
# - une disponibilité alimentaire totale faible
# - une disponibilité totale de protéines faible
# - Un PIB par habitant élevé
# - une proportion de protéines faible

# %% [markdown]
# <a id="chapitre_2"></a>
# ## <span style="color: #030aa4">Méthode du dendrogramme</span>

# %% [markdown]
# <a id="chapitre_2_1"></a>
# ### <span style="color: #a40334">Dendrogramme</span>

# %%
def plot_dendrogram(Z, names):
    plt.figure(figsize=(10,25))
    plt.title('Hierarchical Clustering Dendrogram')
    plt.xlabel('distance')
    dendrogram(
        Z,
        labels = names,
        orientation = "left",
    )
    #plt.savefig('dendrogramme.png', dpi=320, format='png', bbox_inches='tight')
    plt.show()
    
    
from scipy.cluster.hierarchy import linkage, fcluster


# préparation des données pour le clustering
X = data.values
names = data.index

# Centrage et Réduction
std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)

# Clustering hiérarchique
Z = linkage(X_scaled, 'ward')

# Affichage du dendrogramme
plot_dendrogram(Z, names)

# %% [markdown]
# <a id="chapitre_2_2"></a>
# ### <span style="color: #a40334">Coupage du dendrogramme en 5 clusters</span>

# %%
clusters = fcluster(Z, 5, criterion='maxclust')

dataClusters = pd.DataFrame({"cluster": clusters, "Zone": names})

dataClusters.head(3)

#dataClusters.to_csv('P5_03_Liste_pays.csv',index=False)
# Out:
#    cluster         Zone
# 0        5      Arménie
# 1        1  Afghanistan
# 2        3      Albanie

# %% [markdown]
# <a id="chapitre_2_3"></a>
# ### <span style="color: #a40334">Nombre de pays par clusters</span>

# %%
dataClusters["Nombre d'états"]=1

dataClusters.groupby('cluster')["Nombre d'états"].sum()
# Out:
# cluster
# 1    64
# 2    20
# 3    19
# 4    22
# 5    40
# Name: Nombre d'états, dtype: int64

# %% [markdown]
# <a id="chapitre_2_4"></a>
# ### <span style="color: #a40334">Analyse des clusters</span>

# %%
cluster = sorted(dataClusters.cluster.unique())

for i in cluster :
    print("Pays du cluster ",i , ":")
    print(" ")
    print(dataClusters[dataClusters.cluster==i].Zone.unique())
    print(" ")
# Out:
# Pays du cluster  1 :
#
# ['Afghanistan' 'Angola' 'Bangladesh' 'Bolivie (État plurinational de)'
#  'Botswana' 'Belize' 'Îles Salomon' 'Cameroun' 'Cabo Verde'
#  'République centrafricaine' 'Sri Lanka' 'Tchad' 'Congo' 'Bénin'
#  'Équateur' 'El Salvador' 'Djibouti' 'Gambie' 'Ghana' 'Guatemala' 'Guinée'
#  'Haïti' 'Honduras' 'Inde' 'Indonésie' 'Iraq' "Côte d'Ivoire" 'Jordanie'
#  'Kenya' 'Cambodge' 'République populaire démocratique de Corée' 'Liban'
#  'Lesotho' 'Libéria' 'Madagascar' 'Malawi' 'Mali' 'Mauritanie'
#  'Mozambique' 'Namibie' 'Népal' 'Vanuatu' 'Nicaragua' 'Niger' 'Nigéria'
#  'Pakistan' 'Philippines' 'Guinée-Bissau' 'Timor-Leste' 'Zimbabwe'
#  'Rwanda' 'Sao Tomé-et-Principe' 'Sénégal' 'Sierra Leone' 'Tadjikistan'
#  'Eswatini' 'République-Unie de Tanzanie' 'Togo' 'Ouganda' 'Burkina Faso'
#  'Éthiopie' 'Yémen' 'Zambie' 'Soudan']
#
# Pays du cluster  2 :
#
# ['Australie' 'Autriche' 'Canada' 'Danemark' 'Finlande' 'France'
#  'Allemagne' 'Chine - RAS de Hong-Kong' 'Islande' 'Irlande' 'Israël'
#  'Koweït' 'Pays-Bas' 'Norvège' 'Suède' 'Suisse' 'Émirats arabes unis'
#  "États-Unis d'Amérique" 'Belgique' 'Luxembourg']
#
# Pays du cluster  3 :
#
# ['Albanie' 'Bélarus' 'Estonie' 'Grèce' 'Hongrie' 'Croatie' 'Italie'
#  'République de Corée' 'Lettonie' 'Lituanie' 'Malte' 'Tchéquie' 'Pologne'
#  'Portugal' 'Roumanie' 'Fédération de Russie' 'Slovénie' 'Espagne'
#  'Monténégro']
#
# Pays du cluster  4 :
#
# ['Algérie' 'Chili' 'Colombie' 'Costa Rica' 'Azerbaïdjan' 'Égypte' 'Gabon'
#  'Kiribati' 'Kirghizistan' 'Malaisie' 'Maldives' 'Mexique' 'Maroc'
#  'Panama' 'Pérou' 'Arabie saoudite' 'Afrique du Sud' 'Turkménistan' 'Oman'
#  'Tunisie' 'Turquie' 'Viet Nam']
#
# Pays du cluster  5 :
#
# ['Arménie' 'Antigua-et-Barbuda' 'Argentine' 'Bahamas' 'Barbade' 'Brésil'
#  'Bulgarie' 'Myanmar' 'Chine, continentale' 'Cuba' 'Chypre' 'Dominique'
#  'République dominicaine' 'Fidji' 'Polynésie française' 'Géorgie'
#  'Bosnie-Herzégovine' 'Grenade' 'Kazakhstan' 'Jamaïque' 'Japon' 'Maurice'
#  'Mongolie' 'République de Moldova' 'Nouvelle-Calédonie'
#  'Macédoine du Nord' 'Nouvelle-Zélande' 'Paraguay' 'Saint-Kitts-et-Nevis'
#  'Sainte-Lucie' 'Saint-Vincent-et-les Grenadines' 'Slovaquie' 'Suriname'
#  'Thaïlande' 'Trinité-et-Tobago' 'Ukraine' 'Uruguay'
#  'Venezuela (République bolivarienne du)' 'Samoa' 'Serbie']

# %% [markdown]
# - Les **clusters 2 et 3** regroupent les pays où les disponibilités en nourriture sont élevées et ne semblent pas être nos clusters cibles.
# - Le **cluster 1** regroupe les pays les plus pauvres.
# - Les **clusters 4 et 5** regroupent des pays aux critères variés : économie instable, disparités, faible proportion de protéines d'origine animale...

# %% [markdown]
# <a id="chapitre_2_5"></a>
# ### <span style="color: #a40334">Analyse en composantes principales</span>

# %%
# choix du nombre de composantes à calculer
n_comp = 5

# Calcul des composantes principales
pca = decomposition.PCA(n_components=n_comp)
pca.fit(X_scaled)

# Eboulis des valeurs propres

def display_scree_plot(pca):
    scree = pca.explained_variance_ratio_*100
    plt.bar(np.arange(len(scree))+1, scree)
    plt.plot(np.arange(len(scree))+1, scree.cumsum(),c="red",marker='o')
    plt.xlabel("rang de l'axe d'inertie")
    plt.ylabel("pourcentage d'inertie")
    plt.title("Eboulis des valeurs propres")
    plt.show(block=False)

display_scree_plot(pca)

# %% [markdown]
# Selon la méthode du coude, la courbe baisse au niveau du deuxième rang. Les deux premiers rangs rassemblent plus de 80% de l'inertie totale. **On ne retient donc que les deux premiers axes d'inertie**.

# %%
def display_circles(pcs, n_comp, pca, axis_ranks, labels=None, label_rotation=0, lims=None):
    for d1, d2 in axis_ranks:
        if d2 < n_comp:

            # initialisation de la figure
            fig, ax = plt.subplots(figsize=(7,6))

            # détermination des limites du graphique
            if lims is not None :
                xmin, xmax, ymin, ymax = lims
            elif pcs.shape[1] < 30 :
                xmin, xmax, ymin, ymax = -1, 1, -1, 1
            else :
                xmin, xmax, ymin, ymax = min(pcs[d1,:]), max(pcs[d1,:]), min(pcs[d2,:]), max(pcs[d2,:])

            # affichage des flèches
            # s'il y a plus de 30 flèches, on n'affiche pas le triangle à leur extrémité
            if pcs.shape[1] < 30 :
                plt.quiver(np.zeros(pcs.shape[1]), np.zeros(pcs.shape[1]),
                   pcs[d1,:], pcs[d2,:], 
                   angles='xy', scale_units='xy', scale=1, color="grey")
                # (voir la doc : https://matplotlib.org/api/_as_gen/matplotlib.pyplot.quiver.html)
            else:
                lines = [[[0,0],[x,y]] for x,y in pcs[[d1,d2]].T]
                ax.add_collection(LineCollection(lines, axes=ax, alpha=.1, color='black'))
            
            # affichage des noms des variables  
            if labels is not None:  
                for i,(x, y) in enumerate(pcs[[d1,d2]].T):
                    if x >= xmin and x <= xmax and y >= ymin and y <= ymax :
                        plt.text(x, y, labels[i], fontsize='14', ha='center', va='center', rotation=label_rotation, color="blue", alpha=0.5)
            
            # affichage du cercle
            circle = plt.Circle((0,0), 1, facecolor='none', edgecolor='b')
            plt.gca().add_artist(circle)

            # définition des limites du graphique
            plt.xlim(xmin, xmax)
            plt.ylim(ymin, ymax)
        
            # affichage des lignes horizontales et verticales
            plt.plot([-1, 1], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-1, 1], color='grey', ls='--')

            # nom des axes, avec le pourcentage d'inertie expliqué
            plt.xlabel('F{} ({}%)'.format(d1+1, round(100*pca.explained_variance_ratio_[d1],1)))
            plt.ylabel('F{} ({}%)'.format(d2+1, round(100*pca.explained_variance_ratio_[d2],1)))

            plt.title("Cercle des corrélations (F{} et F{})".format(d1+1, d2+1))
            #plt.savefig("Cercle des corrélations.png")
            plt.show(block=False)
        

    
# choix du nombre de composantes à calculer
n_comp = 5

# sélection des colonnes à prendre en compte dans l'ACP
data_pca = data[['diff_pop',
                 'disp_alim',
                 'disp_prot',
                 'pib_hab',
                 'prop_prot']]

# préparation des données pour l'ACP
data_pca = data_pca.fillna(data_pca.mean())

X = data_pca.values
names = data.index
features = data.columns

# Centrage et Réduction
std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)

# Cercle des corrélations
pcs = pca.components_
display_circles(pcs, n_comp, pca, [(0,1)], labels = np.array(features))

# %% [markdown]
# **Description des variables synthétiques :**
#     - F1 est :
#         - faiblement anticorrélée avec la différence de population entre 2016 et 2017
#         - corrélée avec la disponibilité alimentaire totale
#         - corrélée avec la disponibilité totale de protéines en quantité
#         - corrélée avec la proportion de protéine d'origine animale
#         - corrélée avec le PIB par habitant
#     - F2 est :
#         - fortement corrélée avec la différence de population entre 2016 et 2017
#         - faiblement corrélée avec la disponibilité alimentaire totale
#         - faiblement corrélée avec la disponibilité totale de protéines en quantité
#         - faiblement anticorrélée avec la proportion de protéine d'origine animale
#         - corrélée avec le PIB par habitant
#
# **Nous pouvons donc identifier F1 et F2 de la façon suivante :**
# - **F1 : accès à la nourriture**
# - **F2 : démographie/ économie**
#
# **Nous cherchons donc le cluster avec des valeurs moyennes de :**
# - **F1 négatives**
# - **F2 positives.**

# %% [markdown]
# <a id="chapitre_2_6"></a>
# ### <span style="color: #a40334">Calcul des composantes principales et moyennes</span>

# %%
X_scaled = preprocessing.StandardScaler().fit_transform(data.values)
pca = decomposition.PCA(n_components=2)
X_projected = pca.fit_transform(X_scaled)
dataCP= pd.DataFrame(X_projected, index=data.index, columns = ["F"+str(i+1) for i in range(2)])

dataParCluster = pd.merge(dataClusters,dataCP, on='Zone')
dataParCluster = dataParCluster.drop(columns="Nombre d'états")

dataParCluster.groupby('cluster').mean()
# Out:
#                F1        F2
# cluster
# 1       -1.885886  0.175614
# 2        2.935202  1.223856
# 3        2.089808 -0.708845
# 4        0.050083  0.311895
# 5        0.529611 -0.727752

# %% [markdown]
# En affichant les moyennes de chaque variables synthétiques,  nous trouvons un seul cluster avec F1 négatif et F2 positif : **le cluster 1**
#
# **Selon la méthode du dendrogramme, les individus du cluster 1 sont les pays à cibler pour notre étude de marché.**

# %% [markdown]
# <a id="chapitre_3"></a>
# ## <span style="color: #030aa4">Caractérisation des clusters selon les variables : méthode K-Means</span>

# %% [markdown]
# Pour caractériser les clusters selon les variables , nous allons afficher les positions de leur centre de classe sur le premier plan factoriel.

# %%
from sklearn.cluster import KMeans

# Nombre de clusters souhaités
n_clust = 5

# préparation des données pour le clustering
X = data.values

# Réduction
X_scaled = preprocessing.StandardScaler().fit_transform(X)

# Clustering par K-means
km = KMeans(n_clusters=n_clust)
km.fit(X_scaled)

# Récupération des clusters attribués à chaque individu
clusters = km.labels_

# Affichage du clustering par projection des individus sur le premier plan factoriel
pca = decomposition.PCA(n_components=2).fit(X_scaled)
X_projected = pca.transform(X_scaled)

# Affichage des positions des centres de classes
plt.figure(figsize=(12,8))
centroids = km.cluster_centers_

centroids_projected = pca.transform(centroids)

scatter = plt.scatter(centroids_projected[:,0],centroids_projected[:,1], cmap = 'jet')
plt.title("Projection des {} centres sur le 1er plan factoriel".format(len(centroids)))
plt.show()

# %% [markdown]
# De gauche à droite :
#    - **premier centroïde** :
#         - F1 négatif (valeurs les plus basses) et F2 positif signifiant:
#             - Une disponibilité totale, une disponibilité en protéines et une proportion **au plus bas**
#             - Une différence de population et un PIB par habitants **élevés**
#    - **deuxième centroïde** :
#         - F1 négatif et F2 positif signifiant:
#             - Une disponibilité totale, une disponibilité en protéines et une proportion **très faibles**
#             - Une différence de population et un PIB par habitants **peu élevés**
#    - **troisième centroïde** :
#         - F1 légèrement supérieur à 0 et F2 négatif (valeurs les plus basses) signifiant:
#             - Une disponibilité totale, une disponibilité en protéines et une proportion **faibles**
#             - Une différence de population et un PIB par habitants **très faibles**
#    - **quatrième centroïde** :
#         - F1 supérieur à 0 et F2 largement inférieur à 0 signifiant:
#             - Une disponibilité totale, une disponibilité en protéines et une proportion **élevées**
#             - Une différence de population et un PIB par habitants **très faibles**
#    - **cinquième centroïde** :
#         - F1 positif (valeurs les plus hautes) et F2 positif (valeurs les plus hautes) signifiant:
#             - Une disponibilité totale, une disponibilité en protéines et une proportion **au maximum**
#             - Une différence de population et un PIB par habitants **très élevés**

# %% [markdown]
# **Il y a un cluster qui regroupe nos pays cibles : c'est celui du premier centroïde.**
#
# **Il faut identifier ce cluster.**

# %%
#centroids_df = pd.DataFrame(centroids)
#centroids_df.rename(columns=lambda x: x+1, inplace=True)
#centroids_df.to_csv('P5_04_Coordonnees_Centroides.csv',index=False)

# %% [markdown]
# <a id="chapitre_4"></a>
# ## <span style="color: #030aa4">Visualisation dans le premier plan factoriel obtenu par ACP</span>

# %% [markdown]
# <a id="chapitre_4_1"></a>
# ### <span style="color: #a40334">Méthode du dendrogramme</span>

# %%
d1 = 0
d2 = 1

# Coordonnées F1, F2 de chaque point calculées dans dataframe 'dataParCluster'

# Coordonnées F1, F2 de chaque centroïde calculées depuis le coupage du dendrogramme :

centroids_Dendrogramme = dataParCluster.groupby('cluster').mean()\
                                       .reset_index()

fig = plt.figure(figsize=(14,12))
cluster_values = list(dataClusters.cluster)
classes = list(np.unique(dataClusters.cluster))
classes = ['Cluster ' + str(x) for x in classes]
centroid_cluster_values = list(centroids_Dendrogramme.cluster)

# Nuage de points :

scatter = plt.scatter(dataParCluster['F1'], dataParCluster['F2'], c=cluster_values, cmap = 'jet')

# Ajout des abréviations des zones sur chaque point :

first_letters = dataParCluster['Zone'].astype(str).str[:3]
for i, txt in enumerate(first_letters):
    plt.annotate(txt, (dataParCluster['F1'][i], dataParCluster['F2'][i]))

# Superposition des centroïdes calculés depuis dendrogramme :

centroid_scatter = plt.scatter(centroids_Dendrogramme['F1'],
                               centroids_Dendrogramme['F2'],
                               marker = 's',
                               c = centroid_cluster_values,
                               cmap = 'jet',
                               s = 500)

boundary = np.max(np.abs(X_projected[:, [0,1]])) * 1.1
plt.xlim([-boundary,boundary])
plt.ylim([-boundary,boundary])

# Affichage des axes
plt.plot([-100, 100], [0, 0], color = 'grey', ls='--')
plt.plot([0, 0], [-100, 100] , color = 'grey', ls='--')

# Nom des axes
plt.xlabel("F{} ({}%)".format(d1+1, round(100*pca.explained_variance_ratio_[d1],1)))
plt.ylabel("F{} ({}%)".format(d2+1, round(100*pca.explained_variance_ratio_[d2],1)))

plt.title("Projection des {} individus sur le 1e plan factoriel, méthode dendrogramme".format(X_projected.shape[0]))
plt.legend(handles = scatter.legend_elements()[0], labels = classes)
#plt.savefig("Projection des 165 individus sur le 1er plan factoriel, méthode dendrogramme")
plt.show(block=False)

# %% [markdown]
# <a id="chapitre_4_2"></a>
# ### <span style="color: #a40334">Méthode K-Means</span>

# %%
# Création du dataframe avec les zones, les clusters, F1 et F2 
# où F1 et F2 sont calculées à partir de X_projected :

dataParCluster_kmeans = pd.DataFrame({'Zone':data.index,
                                      'cluster':clusters,
                                      'F1':X_projected[:,0],
                                      'F2':X_projected[:,1]})
dataParCluster_kmeans.head(3)
# Out:
#           Zone  cluster        F1        F2
# 0      Arménie        2  0.841751 -0.824472
# 1  Afghanistan        0 -2.915168  0.306289
# 2      Albanie        2  2.136033 -0.907819

# %%
# Création du dataframe avec les centroïdes calculés avec l'algorithme de K-Means :

centroids_kmeans = pd.DataFrame({'centroid':range(1,6),
                                    'F1':centroids_projected[:,0],
                                    'F2':centroids_projected[:,1]})
centroids_kmeans["nombre d'états"] = dataParCluster_kmeans.groupby('cluster')['Zone'].count()

centroids_kmeans
# Out:
#    centroid        F1        F2  nombre d'états
# 0         1 -2.049576  0.265716              55
# 1         2 -0.041075  0.362263              24
# 2         3  1.613225 -0.656682              36
# 3         4  3.023284  1.199769              19
# 4         5 -0.058259 -0.724636              31

# %% [markdown]
# **Le nombre d'états par cluster diffère de celui issu du dendrogramme.**
#
# **La méthode du dendrogramme et celle de l'algorithme de K-Means donnent donc des résultats différents.**
#
# **Il va falloir déterminer quelle méthode donne le meilleur résultat.**

# %%
d1 = 0
d2 = 1

fig = plt.figure(figsize=(14,12))
cluster_values = list(dataParCluster_kmeans.cluster)
classes = list(dataParCluster_kmeans.cluster.unique())
classes = ['Cluster ' + str(x) for x in classes]

centroid_cluster_values = list(centroids_kmeans.centroid)


scatter = plt.scatter(dataParCluster_kmeans['F1'], dataParCluster_kmeans['F2'], c=cluster_values, cmap = 'jet')

# Ajout des abréviations des zones sur chaque point :

first_letters = dataParCluster_kmeans['Zone'].astype(str).str[:3]
for i, txt in enumerate(first_letters):
    plt.annotate(txt, (dataParCluster_kmeans['F1'][i], dataParCluster_kmeans['F2'][i]))


centroid_scatter = plt.scatter(centroids_kmeans['F1'],
                               centroids_kmeans['F2'],
                               marker = 's',
                               c=centroid_cluster_values,
                               cmap = 'jet',
                               s=500)


boundary = np.max(np.abs(X_projected[:, [0,1]])) * 1.1
plt.xlim([-boundary,boundary])
plt.ylim([-boundary,boundary])

# Affichage des axes
plt.plot([-100, 100], [0, 0], color = 'grey', ls='--')
plt.plot([0, 0], [-100, 100] , color = 'grey', ls='--')

# Nom des axes
plt.xlabel("F{} ({}%)".format(d1+1, round(100*pca.explained_variance_ratio_[d1],1)))
plt.ylabel("F{} ({}%)".format(d2+1, round(100*pca.explained_variance_ratio_[d2],1)))

plt.title("Projection des {} individus sur le 1e plan factoriel, méthode K-Means".format(X_projected.shape[0]))
#plt.savefig('Projection_K_Means.jpg')
plt.show(block=False)

# %% [markdown]
# **La numérotation des clusters n'est pas la même qu'avec la méthode du dendrogramme.**
#
# **Le cluster qui rassemble nos pays cibles selon la méthode K-Means est le cluster le plus à gauche.**

# %% [markdown]
# <a id="chapitre_5"></a>
# ## <span style="color: #030aa4">Liste des pays à cibler</span>

# %% [markdown]
# **Les pays du cluster 1 pour chaque méthode du dendrogramme peuvent être nos pays cibles**.
#
# **Les pays du cluster le plus à gauche pour la méthode K-Means peuvent aussi être nos pays cibles.**
#
# **Pour chaque méthode, ces clusters ont des pays en commun mais différent par leur nombre. Nous allons donc comparer leurs pays ayant les valeurs de F1 les plus basses et celles de F2 les plus hautes.**
#
# Préalablement, ces clusters regroupant les pays les moins riches, **il convient d'abord d'identitifier les pays plus pauvres de ce cluster et d'en supprimer ceux sous le seuil de pauvreté**.
#
# **Le seuil de pauvreté se situe à 1,9 dollars US par habitant par jour, soit 693,5 dollars US par an.**
#
# Source : https://www.banquemondiale.org/fr/research/brief/poverty-and-shared-prosperity-2018-piecing-together-the-poverty-puzzle-frequently-asked-questions
#
# Ensuite, nous allons sélectionner les 10 pays avec la valeur de **F1 la plus basse** et les 10 pays avec la valeur de **F2 la plus élevée**.
#
# **Les pays communs à ces deux classements seront nos pays cibles pour chaque méthode.**
#
# **Enfin, nous comparerons les classements pour chaque méthode.**

# %%
dataCluster1_dendrogramme = dataParCluster[dataParCluster.cluster==1]\
                        .drop(columns=["cluster"])

dataPIB = data.loc[ : ,('pib_hab')]
dataPIB = dataPIB.reset_index()

dataCluster1_dendrogramme = pd.merge(dataCluster1_dendrogramme,dataPIB)
dataCluster1_dendrogramme = dataCluster1_dendrogramme[dataCluster1_dendrogramme['pib_hab']>693.5]

# Top 10 selon F1 au minimum :
PaysCiblesF1Min_dendrogramme = dataCluster1_dendrogramme.sort_values('F1')\
                                           .drop(columns=['F2'])\
                                           .head(10)

# Top 10 selon F2 au maximum
PaysCiblesF2Max_dendrogramme = dataCluster1_dendrogramme.sort_values('F2', ascending = False)\
                                           .drop(columns=['F1'])\
                                           .head(10)
 

# Pays cibles : pays communs des deux classements :

PaysCibles_dendrogramme = PaysCiblesF1Min_dendrogramme[['Zone']].merge(PaysCiblesF2Max_dendrogramme[['Zone']]).drop_duplicates()

PaysCibles_dendrogramme
# Out:
#                           Zone
# 0                      Ouganda
# 1  République-Unie de Tanzanie
# 2                       Angola

# %% [markdown]
# **Selon le dendrogramme, ces trois pays sont nos pays cibles :**
# - **Ouganda**
# - **République_Unie de Tanzanie**
# - **Angola**

# %%
#### LE NUMÉRO DU CLUSTER EST ATTRIBUÉ ALÉATOIREMENT ET CHANGE À CHAQUE EXÉCUTION DU CODE 

dataCluster_kmeans = dataParCluster_kmeans[dataParCluster_kmeans.cluster==0]\
                                   .drop(columns=["cluster"])

dataPIB = data.loc[ : ,('pib_hab')]
dataPIB = dataPIB.reset_index()

dataCluster_kmeans = pd.merge(dataCluster_kmeans,dataPIB)
dataCluster_kmeans = dataCluster_kmeans[dataCluster_kmeans['pib_hab']>693.5]

# Top 10 selon F1 au minimum :
PaysCiblesF1Min_kmeans = dataCluster_kmeans.sort_values('F1')\
                                           .drop(columns=['F2'])\
                                           .head(10)

# Top 10 selon F2 au maximum
PaysCiblesF2Max_kmeans = dataCluster_kmeans.sort_values('F2', ascending = False)\
                                           .drop(columns=['F1'])\
                                           .head(10)
 

# Pays cibles : pays communs des deux classements :

PaysCibles_kmeans = PaysCiblesF1Min_kmeans[['Zone']].merge(PaysCiblesF2Max_kmeans[['Zone']]).drop_duplicates()

PaysCibles_kmeans
# Out:
#                           Zone
# 0                      Ouganda
# 1  République-Unie de Tanzanie
# 2                       Angola

# %% [markdown]
# **Selon la méthode de K-Means, les trois pays à cibler sont les mêmes qu'avec la méthode du dendrogramme.**

# %% [markdown]
# <a id="chapitre_6"></a>
# ## <span style="color: #030aa4">Caractéristiques des pays à cibler</span>

# %% [markdown]
# ### <span style="color: #a40334">Moyennes mondiales</span>

# %%
dataMean = data.reset_index()\
               .mean()

dataMean
# Out:
# diff_pop     1.277463e+00
# disp_alim    1.040597e+06
# disp_prot    2.949819e+04
# pib_hab      1.373615e+04
# prop_prot    4.258979e+01
# dtype: float64

# %% [markdown]
# ### <span style="color: #a40334">Caractéristiques des pays cibles</span>

# %%
dataPaysCibles = data.reset_index()

dataPaysCibles = pd.merge(PaysCibles_dendrogramme,dataPaysCibles)

dataPaysCibles
# Out:
#                           Zone  diff_pop  disp_alim  disp_prot      pib_hab  \
# 0                      Ouganda  3.827117   782560.0   19107.75   910.269755
# 1  République-Unie de Tanzanie  3.037009   874540.0   21819.70   937.301492
# 2                       Angola  3.377933   828550.0   19750.15  3409.929285
#
#    prop_prot
# 0  20.783190
# 1  15.623954
# 2  30.456478

# %% [markdown]
# Les trois pays ont une croissance démographique **deux fois supérieure à la moyenne mondiale par pays**.
#
# Leur disponibilité alimentaire totale, leur disponibilité en quantité de protéines et leur proportion de protéine animales sont **inférieure à la moyenne mondiale par pays**.
#
# Leur PIB/habitant reste par contre **inférieur à la moyenne mondiale par pays** mais assure un pouvoir d'achat suffisant pour la vente de poulet.

# %% [markdown]
# <a id="chapitre_7"></a>
# ## <span style="color: #030aa4">Test d'adéquation</span>

# %% [markdown]
# Il faut trouver une variable dont la loi est **normale**.
# Les variables sont continues, nous allons utiliser le test de Shapiro-Wilk qui teste l'hypothèse nulle selon laquelle un échantillon est normalement distribué.

# %%
import scipy.stats

# %%
def test_adequation(df,column) :
    
    x = df[column]
    pvalue = scipy.stats.shapiro(x)[0]
    print('Test statistique pour la normalité des données : {}'.format(column))
    print('Hypothèse nulle : les données mentionnées suivent une loi normale')

    if pvalue > 0.05 :
        print("La p-value est égale à", round(pvalue,2),".")
        print("Elle est est supérieure au niveau de test 5%.")
        print("On ne peut pas rejeter l'hypothèse nulle.")
    else:
        print("La p-value est égale à", round(pvalue,2),".")
        print("Elle est est inférieure au niveau de test 5%.")
        print("On peut rejeter l'hypothèse nulle.")
        print("L'échantillon n'est pas normalement distribué.")
            
test_adequation(data, 'diff_pop')
print("-"*50)
print(" ")
test_adequation(data, 'disp_alim')
print("-"*50)
print(" ")
test_adequation(data, 'disp_prot')
print("-"*50)
print(" ")
test_adequation(data, 'pib_hab')
print("-"*50)
print(" ")
test_adequation(data, 'prop_prot')
# Out:
# Test statistique pour la normalité des données : diff_pop
# Hypothèse nulle : les données mentionnées suivent une loi normale
# La p-value est égale à 0.99 .
# Elle est est supérieure au niveau de test 5%.
# On ne peut pas rejeter l'hypothèse nulle.
# --------------------------------------------------
#
# Test statistique pour la normalité des données : disp_alim
# Hypothèse nulle : les données mentionnées suivent une loi normale
# La p-value est égale à 0.98 .
# Elle est est supérieure au niveau de test 5%.
# On ne peut pas rejeter l'hypothèse nulle.
# --------------------------------------------------
#
# Test statistique pour la normalité des données : disp_prot
# Hypothèse nulle : les données mentionnées suivent une loi normale
# La p-value est égale à 0.98 .
# Elle est est supérieure au niveau de test 5%.
# On ne peut pas rejeter l'hypothèse nulle.
# --------------------------------------------------
#
# Test statistique pour la normalité des données : pib_hab
# Hypothèse nulle : les données mentionnées suivent une loi normale
# La p-value est égale à 0.7 .
# Elle est est supérieure au niveau de test 5%.
# On ne peut pas rejeter l'hypothèse nulle.
# --------------------------------------------------
#
# Test statistique pour la normalité des données : prop_prot
# Hypothèse nulle : les données mentionnées suivent une loi normale
# La p-value est égale à 0.96 .
# Elle est est supérieure au niveau de test 5%.
# On ne peut pas rejeter l'hypothèse nulle.

# %% [markdown]
# On ne peut rejeter l'hypothèse nulle pour aucune variable. Ce qui signifie qu'elles peuvent toutes suivre une loi normale mais à ce stade du test, il n'est pas possible de s'en assurer.
#
# #### Affichage de la distribution de la différence de population entre 2016 et 2017 et comparaison avec une loi normale :

# %%
from scipy.stats import norm
sns.distplot(data['diff_pop'], fit=norm, kde=False)
# plt.savefig("Distribution_Diff_pop.png")

# %% [markdown]
# **La distribution de la différence de population suit la loi normale.**

# %% [markdown]
# <a id="chapitre_8"></a>
# ## <span style="color: #030aa4">Test de comparaison</span>

# %% [markdown]
# Le test de comparaison consiste à comparer la variance et la moyenne de deux variables.
# Préalablement, il faut vérifier que les variables comparées sont **gaussiennes**.
#
# #### Test d'adéquation des variables F1 des clusters 2 et 3  pour savoir si les variables sont gaussiennes :

# %%
dataParCluster2 = dataParCluster[dataParCluster.cluster==2]
dataParCluster3 = dataParCluster[dataParCluster.cluster==3]

print("Test d'adéquation de la variable F1 du cluster 2 :")
print(" ")
test_adequation(dataParCluster2,'F1')
print(" ")
print("-"*50)
print(" ")
print("Test d'adéquation de la variable F1 du cluster 3 :")
print(" ")
test_adequation(dataParCluster3, 'F1')
# Out:
# Test d'adéquation de la variable F1 du cluster 2 :
#
# Test statistique pour la normalité des données : F1
# Hypothèse nulle : les données mentionnées suivent une loi normale
# La p-value est égale à 0.94 .
# Elle est est supérieure au niveau de test 5%.
# On ne peut pas rejeter l'hypothèse nulle.
#
# --------------------------------------------------
#
# Test d'adéquation de la variable F1 du cluster 3 :
#
# Test statistique pour la normalité des données : F1
# Hypothèse nulle : les données mentionnées suivent une loi normale
# La p-value est égale à 0.96 .
# Elle est est supérieure au niveau de test 5%.
# On ne peut pas rejeter l'hypothèse nulle.

# %% [markdown]
# #### Histogrammes des variables F1 des clusters 2 et 3 :

# %%
xbar = np.mean(dataParCluster2.F1)
sprime = np.std(dataParCluster2.F1)
fig, ax = plt.subplots()
n, bins, patches = ax.hist(dataParCluster2.F1,normed = True, bins = range(0,5))
bins = np.arange(0,5,0.1)
y = scipy.stats.norm.pdf(bins, xbar,sprime)
ax.plot(bins, y, '--')
ax.set_xlabel('Smarts')
ax.set_title("Histogramme cluster 2 (F1) et densité normale")
#plt.savefig("Histogramme cluster 2 (F1) et densité normale")

# %%
xbar = np.mean(dataParCluster3.F1)
sprime = np.std(dataParCluster3.F1)
fig, ax = plt.subplots()
n, bins, patches = ax.hist(dataParCluster3.F1,normed = True, bins = range(0,5))
bins = np.arange(0,5,0.1)
y = scipy.stats.norm.pdf(bins, xbar,sprime)
ax.plot(bins, y, '--')
ax.set_xlabel('Smarts')
ax.set_title("Histogramme cluster 3 (F1) et densité normale")
#plt.savefig("Histogramme cluster 3 (F1) et densité normale")

# %% [markdown]
# Les deux variables sont gaussiennes, nous pouvons appliquer un test de comparaison.
#
# #### Test de comparaison des clusters 2 et 3 :

# %%
dataParCluster2 = dataParCluster[dataParCluster.cluster==2]
dataParCluster3 = dataParCluster[dataParCluster.cluster==3]

print("Test de comparaison de la variable F1 des clusters 2 et 3 :")
print(" ")

# Égalité des variances :

pvalueVar = scipy.stats.bartlett(dataParCluster2.F1,dataParCluster3.F1)[1]

if pvalueVar > 0.05 :
    print("Pour les variances, la p-value est égale à", round(pvalueVar,2),".")
    print("Elle est est supérieure au niveau de test 5%.")
    print("On ne rejette pas l'égalité des variances.")
else:
    print("Pour les variances, la p-value est égale à", round(pvalueVar,2),".")
    print("Elle est est inférieure au niveau de test 5%.")
    print("On peut rejeter l'hypothèse d'égalité des variances.")

print(" ")
print("-"*60)
print(" ")
    
# Égalité des moyennes :

pvalueMean = scipy.stats.ttest_ind(dataParCluster2.F1,dataParCluster3.F1, equal_var=True)[1]

if pvalueMean > 0.05 :
    print("Pour les moyennes, la p-value est égale à", pvalueMean,".")
    print("Elle est est supérieure au niveau de test 5%.")
    print("On ne rejette pas l'égalité des moyennes.")
else:
    print("Pour les moyennes, la p-value est égale à", pvalueMean,".")
    print("Elle est est inférieure au niveau de test 5%.")
    print("On peut rejeter l'hypothèse d'égalité des moyennes.")
# Out:
# Test de comparaison de la variable F1 des clusters 2 et 3 :
#
# Pour les variances, la p-value est égale à 0.16 .
# Elle est est supérieure au niveau de test 5%.
# On ne rejette pas l'égalité des variances.
#
# ------------------------------------------------------------
#
# Pour les moyennes, la p-value est égale à 4.287573208677548e-05 .
# Elle est est inférieure au niveau de test 5%.
# On peut rejeter l'hypothèse d'égalité des moyennes.

# %% [markdown]
# L'hypothèse d'égalité des moyennes est rejetée.
#
# **Les clusters 2 et 3 ne suivent pas la même distribution sur la dimension F1.**

# %% [markdown]
# #### Test d'adéquation des variables F2 des clusters 2 et 3  pour savoir si les variables sont gaussiennes :

# %%
dataParCluster2 = dataParCluster[dataParCluster.cluster==2]
dataParCluster3 = dataParCluster[dataParCluster.cluster==3]

print("Test d'adéquation de la variable F2 du cluster 2 :")
print(" ")
test_adequation(dataParCluster2,'F2')
print(" ")
print("-"*50)
print(" ")
print("Test d'adéquation de la variable F2 du cluster 3 :")
print(" ")
test_adequation(dataParCluster3, 'F2')
# Out:
# Test d'adéquation de la variable F2 du cluster 2 :
#
# Test statistique pour la normalité des données : F2
# Hypothèse nulle : les données mentionnées suivent une loi normale
# La p-value est égale à 0.84 .
# Elle est est supérieure au niveau de test 5%.
# On ne peut pas rejeter l'hypothèse nulle.
#
# --------------------------------------------------
#
# Test d'adéquation de la variable F2 du cluster 3 :
#
# Test statistique pour la normalité des données : F2
# Hypothèse nulle : les données mentionnées suivent une loi normale
# La p-value est égale à 0.97 .
# Elle est est supérieure au niveau de test 5%.
# On ne peut pas rejeter l'hypothèse nulle.

# %% [markdown]
# #### Histogrammes des variables F2 des clusters 2 et 3 :

# %%
xbar = np.mean(dataParCluster2.F2)
sprime = np.std(dataParCluster2.F2)
fig, ax = plt.subplots()
n, bins, patches = ax.hist(dataParCluster2.F2,normed = True, bins = range(-2,5))
bins = np.arange(-2,5,0.1)
y = scipy.stats.norm.pdf(bins, xbar,sprime)
ax.plot(bins, y, '--')
ax.set_xlabel('Smarts')
ax.set_title("Histogramme cluster 2 (F2) et densité normale")
#plt.savefig("Histogramme cluster 2 (F2) et densité normale")

# %%
xbar = np.mean(dataParCluster3.F2)
sprime = np.std(dataParCluster3.F2)
fig, ax = plt.subplots()
n, bins, patches = ax.hist(dataParCluster3.F2,normed = True, bins = range(-3,5))
bins = np.arange(-3,5,0.1)
y = scipy.stats.norm.pdf(bins, xbar,sprime)
ax.plot(bins, y, '--')
ax.set_xlabel('Smarts')
ax.set_title("Histogramme cluster 3 (F2) et densité normale")
#plt.savefig("Histogramme cluster 3 (F2) et densité normale")

# %% [markdown]
# Les deux variables sont gaussiennes, nous pouvons appliquer un test de comparaison.
#
# #### Test de comparaison de la variable F2 des clusters 2 et 3 :

# %%
dataParCluster2 = dataParCluster[dataParCluster.cluster==2]
dataParCluster3 = dataParCluster[dataParCluster.cluster==3]

print("Test de comparaison de la variable F2 des clusters 2 et 3 :")
print(" ")

# Égalité des variances :

pvalueVar = scipy.stats.bartlett(dataParCluster2.F2,dataParCluster3.F2)[1]

if pvalueVar > 0.05 :
    print("Pour les variances, la p-value est égale à", round(pvalueVar,2),".")
    print("Elle est est supérieure au niveau de test 5%.")
    print("On ne rejette pas l'égalité des variances.")
else:
    print("Pour les variances, la p-value est égale à", round(pvalueVar,2),".")
    print("Elle est est inférieure au niveau de test 5%.")
    print("On peut rejeter l'hypothèse d'égalité des variances.")

print(" ")
print("-"*60)
print(" ")
    
# Égalité des moyennes :

pvalueMean = scipy.stats.ttest_ind(dataParCluster2.F2,dataParCluster3.F2, equal_var=True)[1]

if pvalueMean > 0.05 :
    print("Pour les moyennes, la p-value est égale à", pvalueMean,".")
    print("Elle est est supérieure au niveau de test 5%.")
    print("On ne rejette pas l'égalité des moyennes.")
else:
    print("Pour les moyennes, la p-value est égale à", pvalueMean,".")
    print("Elle est est inférieure au niveau de test 5%.")
    print("On peut rejeter l'hypothèse d'égalité des moyennes.")
# Out:
# Test de comparaison de la variable F2 des clusters 2 et 3 :
#
# Pour les variances, la p-value est égale à 0.09 .
# Elle est est supérieure au niveau de test 5%.
# On ne rejette pas l'égalité des variances.
#
# ------------------------------------------------------------
#
# Pour les moyennes, la p-value est égale à 1.1554877854791023e-11 .
# Elle est est inférieure au niveau de test 5%.
# On peut rejeter l'hypothèse d'égalité des moyennes.

# %% [markdown]
# L'hypothèse d'égalité des moyennes est rejetée.
#
# **Les clusters 2 et 3 ne suivent pas la même distribution sur la dimension F2.**
