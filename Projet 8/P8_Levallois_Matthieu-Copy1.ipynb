# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests

# %%
source = requests.get('https://scomedy.com/quotes?page=1')

soup = bs(source.text, 'lxml')

# %%
#print(soup.prettify())

# %%
soup = bs(source.text, 'lxml')
quotes = soup.find_all('div', {'class':'quote'})
quote_list = []

print(len(quotes))
print(" ")

for quote in quotes:
    citation = quote.find('p').text
    print(citation)
    print(" ")
    comedian = quote.find('div',class_='comedian').text.split("\xa0")[1].split('\n')[0]
    print(comedian)
    print(" ")
    view = int(quote.find('span',class_='views').text.split(" ")[1])
    print(" ")
    if quote.find('li'):
        tags_for_this_quote = []
        for element in quote.find_all('li'):
            theme = element.text.split("#")[1]
            print(theme)    
    else:
        theme= None
    print(" ")
    X=[citation,comedian,view,theme]
    quote_list.append(X)
    quote_df = pd.DataFrame(quote_list,columns = ['citation','auteur','nbre_vues','theme'])
    quote_df
# Out:
# 15
#
# Well, birthdays are merely symbolic of how another year has gone by and how little we've grown. No matter how desperate we are that someday a better self will emerge, with each flicker of the candles on the cake, we know it's not to be, that for the rest of our sad, wretched pathetic lives, this is who we areto the bitter end. Inevitably, irrevocably; happy birthday? No such thing.
#
# Jerry Seinfeld
#
#
# birthday
#
# My perfect date night: I pick you up. In my Kia Sorrento. You get in. There's candles in the car. You go 'Is that dangerous?" and I go, Yes... but I like danger. We go to your favorite restaurant, and we have a fantastic meal. We come outside and we see my cars on fire. You go, "Aziz, your cars on fire. Aren't you upset?" I pull out a bag of marshmallows and I go, No. I knew this was gonna happen. And then I kiss you. In front of my burning car.
#
# Aziz Ansari
#
#
# danger
# dating
# restaurants
#
# ...

# %%
soup = bs(source.text, 'lxml')
quotes = soup.find_all('div', {'class':'quote'})
quote_list = []
comedian_list = []
view_list = []
theme_list = []



for quote in quotes:
    citation = quote.find('p').text   
    comedian = quote.find('div',class_='comedian').text.split("\xa0")[1].split('\n')[0]   
    view = int(quote.find('span',class_='views').text.split(" ")[1])   
    tags_for_this_quote = []
    
    if quote.find('li'): 
        
        for element in quote.find_all('li'):
            theme = element.text.split("#")[1]
            tags_for_this_quote.append(theme)
        
    else:
        tags_for_this_quote= None
        
    quote_list.append(citation)
    comedian_list.append(comedian)
    view_list.append(view)
    theme_list.append(tags_for_this_quote)
    dict_quote ={'citation':quote_list,'auteur':comedian_list,'nbre_vues':view_list,'theme':theme_list}
    quote_df = pd.DataFrame(dict_quote)
    
quote_df
# Out:
#                                              citation            auteur  \
# 0   Well, birthdays are merely symbolic of how ano...    Jerry Seinfeld
# 1   My perfect date night: I pick you up. In my Ki...       Aziz Ansari
# 2   Jack and Jill went up the hill Both with a buc...  Andrew Dice Clay
# 3   I mean, they don't grade fathers. But if your ...        Chris Rock
# 4   “Money doesn’t buy happiness.” Uh, do you live...       Daniel Tosh
# 5   Rights aren't rights if someone can take them ...     George Carlin
# 6   When I was a kid my parents used to tell me, "...       Emo Philips
# 7   I have this friend who got divorced. I went go...       Brian Regan
# 8   Mama says that, happiness is from magic rays o...      Adam Sandler
# 9   Then Jasper said "Look here, nigger, if anyone...    Dave Chappelle
# 10  My ex-girlfriend had a really weird fetish. Sh...        Bo Burnham
# 11  I was having sex with this girl. And we were t...     Donald Glover
# ...

# %%
source = requests.get('https://scomedy.com/quotes?page=1')
soup = bs(source.text, 'lxml')
quotes = soup.find_all('div', {'class':'quote'})
quote_list = []
comedian_list = []
view_list = []
theme_list = []



for quote in quotes:
    citation = quote.find('p').text
    #print(citation)
    #print(" ")
    comedian = quote.find('div',class_='comedian').text.split("\xa0")[1].split('\n')[0]
    #print(comedian)
    #print(" ")
    view = int(quote.find('span',class_='views').text.split(" ")[1])
    #print(" ")
    tags_for_this_quote = []
    if quote.find('li'): 
        
        for element in quote.find_all('li'):
            theme = element.text.split("#")[1]
            tags_for_this_quote.append(theme)
        #print(tags_for_this_quote)
        #print(theme)
    else:
        tags_for_this_quote= None
        #tags_for_this_quote.append(theme)
        #print(tags_for_this_quote)
        #print(theme)
    #print(" ")
    quote_list.append(citation)
    comedian_list.append(comedian)
    view_list.append(view)
    theme_list.append(tags_for_this_quote)
    dict_quote ={'citation':quote_list,'auteur':comedian_list,'nbre_vues':view_list,'theme':theme_list}
    quote_df = pd.DataFrame(dict_quote)
    #quote_df['theme'] = quote_df['theme'].str.get(0)
quote_df
# Out:
#                                              citation            auteur  \
# 0   Well, birthdays are merely symbolic of how ano...    Jerry Seinfeld
# 1   My perfect date night: I pick you up. In my Ki...       Aziz Ansari
# 2   Jack and Jill went up the hill Both with a buc...  Andrew Dice Clay
# 3   “Money doesn’t buy happiness.” Uh, do you live...       Daniel Tosh
# 4   I mean, they don't grade fathers. But if your ...        Chris Rock
# 5   Rights aren't rights if someone can take them ...     George Carlin
# 6   When I was a kid my parents used to tell me, "...       Emo Philips
# 7   I have this friend who got divorced. I went go...       Brian Regan
# 8   Mama says that, happiness is from magic rays o...      Adam Sandler
# 9   Then Jasper said "Look here, nigger, if anyone...    Dave Chappelle
# 10  My ex-girlfriend had a really weird fetish. Sh...        Bo Burnham
# 11  I was having sex with this girl. And we were t...     Donald Glover
# ...

# %%
quote_df.dtypes
# Out:
# citation     object
# auteur       object
# nbre_vues     int64
# theme        object
# dtype: object

# %%
quote_df['theme'].str.strip("[]")
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# Name: theme, dtype: float64

# %%
#quote_df['theme'] = quote_df['theme'].astype(str).str.replace(r"\[","")
#quote_df['theme'] = quote_df['theme'].astype(str).str.replace(r"\]","")
#quote_df
# Out:
#                                              citation            auteur  \
# 0   Well, birthdays are merely symbolic of how ano...    Jerry Seinfeld
# 1   My perfect date night: I pick you up. In my Ki...       Aziz Ansari
# 2   Jack and Jill went up the hill Both with a buc...  Andrew Dice Clay
# 3   I mean, they don't grade fathers. But if your ...        Chris Rock
# 4   “Money doesn’t buy happiness.” Uh, do you live...       Daniel Tosh
# 5   Rights aren't rights if someone can take them ...     George Carlin
# 6   When I was a kid my parents used to tell me, "...       Emo Philips
# 7   I have this friend who got divorced. I went go...       Brian Regan
# 8   Mama says that, happiness is from magic rays o...      Adam Sandler
# 9   Then Jasper said "Look here, nigger, if anyone...    Dave Chappelle
# 10  My ex-girlfriend had a really weird fetish. Sh...        Bo Burnham
# 11  I was having sex with this girl. And we were t...     Donald Glover
# ...

# %%
quote_df['theme'].tolist
# Out:
# <bound method IndexOpsMixin.tolist of 0                        [birthday]
# 1     [danger, dating, restaurants]
# 2                              None
# 3                              None
# 4                       [happiness]
# 5                      [privileges]
# 6                [parents, flowers]
# 7                   [divorce, golf]
# 8                       [happiness]
# 9                         [sisters]
# 10          [dating, ex girlfriend]
# 11                          [worth]
# 12                         [dreams]
# 13                             None
# 14         [addiction, girlfriends]
# Name: theme, dtype: object>

# %%
#quote_df['theme'] = str(quote_df['theme'])
#quote_df['theme'] = quote_df['theme'].str.replace("[","")
#quote_df['theme'] = quote_df['theme'].str.replace("]","")
#quote_df['theme'] = quote_df['theme'].str[1:-1]
#quote_df['theme'] =  quote_df['theme'].apply(lambda x: x.replace('[','').replace(']','')) 
#quote_df['theme'] = quote_df['theme'].tolist()
#quote_df
#quote_df.iloc[:,3].tolist()
quote_df['theme'] = quote_df['theme'].replace("['", " ")
quote_df['theme'] = quote_df['theme'].str.replace("]","")
quote_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-183-f5eb86820d11> in <module>
#       8 #quote_df.iloc[:,3].tolist()
#       9 quote_df['theme'] = quote_df['theme'].replace("['", " ")
# ---> 10 quote_df['theme'] = quote_df['theme'].str.replace("]","")
#      11 quote_df
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# ...

# %%
df = pd.DataFrame({'Region':['New York','Los Angeles','Chicago'], 'State': ['NY [new york]', '[California]', 'IL']})
df
# Out:
#         Region          State
# 0     New York  NY [new york]
# 1  Los Angeles   [California]
# 2      Chicago             IL

# %%
df.dtypes
# Out:
# Region    object
# State     object
# dtype: object

# %%
df['State'] = df['State'].str.replace(r"\[","")
df['State'] = df['State'].str.replace(r"\]","")
df
# Out:
#         Region        State
# 0     New York  NY new york
# 1  Los Angeles   California
# 2      Chicago           IL

# %%
l = ['a', 2, 'c']
str(l)[1:-1]
# Out:
# "'a', 2, 'c'"
